# %%
# %pylab
import matplotlib.animation as animation

# Msun_ini : 120, 85, 60, 40, 25, 20, 15, 12, 9, 7, 5, 4, 3,
# 2.5, 2, 1.7, 1.5, 1.25, 1, 0.90, 0.80 

M120  = loadtxt('M120.dat')
M85   = loadtxt('M85.dat')
M60   = loadtxt('M60.dat')
M40   = loadtxt('M40.dat')
M25   = loadtxt('M25.dat')
M20   = loadtxt('M20.dat')
M15   = loadtxt('M15.dat')
M12   = loadtxt('M12.dat')
M9    = loadtxt('M9.dat')
M7    = loadtxt('M7.dat')
M5    = loadtxt('M5.dat')
M4    = loadtxt('M4.dat')
M3    = loadtxt('M3.dat')
M2_5  = loadtxt('M2_5.dat')
M2    = loadtxt('M2.dat')
M1_7  = loadtxt('M1_7.dat')
M1_5  = loadtxt('M1_5.dat')
M1_25 = loadtxt('M1_25.dat')
M1    = loadtxt('M1.dat')
M0_9  = loadtxt('M0_9.dat')
M0_8  = loadtxt('M0_8.dat')

print(M120[0,0])
print(M120[2,0])
print(M120[:,0])
datasize = size(M120[:,0])
print('datasize = ', datasize)

title('HR Diagram for Zo = 0.001')
#plot(M0_8[:,0], M0_8[:,1],'o-', markersize=4)
#plot(M1[:,0], M1[:,1],'o-', markersize=4)
#plot(M1_5[:,0], M3[:,1],'x-', markersize=4, label = 'M1_5')
#plot(M3[:,0], M3[:,1],'x-', markersize=4, label = 'M3')
#plot(M7[:,0], M7[:,1],'x-', markersize=4, label = 'M7')
#plot(M15[:,0], M15[:,1],'x-', markersize=4, label = 'M15')
#plot(M25[:,0], M25[:,1],'x-', markersize=4, label = 'M25')
#plot(M85[:,0], M85[:,1],'x-', markersize=4, label = 'M85')


plot(M120[:,0], M120[:,1],'x-', markersize=4, label = 'M120')
plot(M85[:,0], M85[:,1],'x-', markersize=4, label = 'M85')
plot(M60[:,0], M60[:,1],'x-', markersize=4, label = 'M60')
plot(M40[:,0], M40[:,1],'x-', markersize=4, label = 'M40')
plot(M25[:,0], M25[:,1],'x-', markersize=4, label = 'M25')
plot(M20[:,0], M20[:,1],'x-', markersize=4, label = 'M20')
plot(M15[:,0], M15[:,1],'x-', markersize=4, label = 'M15')
plot(M12[:,0], M12[:,1],'x-', markersize=4, label = 'M12')
plot(M9[:,0], M9[:,1],'x-', markersize=4, label = 'M9')
plot(M7[:,0], M7[:,1],'x-', markersize=4, label = 'M7')
plot(M5[:,0], M5[:,1],'x-', markersize=4, label = 'M5')
plot(M4[:,0], M4[:,1],'x-', markersize=4, label = 'M4')
plot(M3[:,0], M3[:,1],'x-', markersize=4, label = 'M3')
plot(M2[:,0], M2[:,1],'x-', markersize=4, label = 'M2')
plot(M2_5[:,0], M2_5[:,1],'x-', markersize=4, label = 'M2_5')
plot(M1_5[:,0], M1_5[:,1],'x-', markersize=4, label = 'M1_5')
plot(M1_7[:,0], M1_7[:,1],'x-', markersize=4, label = 'M1_7')
#plot(M1[:,0], M1[:,1],'x-', markersize=4, label = 'M1')
#plot(M0_8[:,0], M0_8[:,1],'x-', markersize=4, label = 'M0_8')
#plot(M0_9[:,0], M0_9[:,1],'x-', markersize=4, label = 'M0_9')


xlabel('log($T_{eff}$)')
ylabel('log($L$)')
legend()
gca().invert_xaxis()

# it seems that there are some problems in the data vor M0_8 and M1 stars
# because they have strange positions in the plot
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib
# 4.727
# 4.698
# [ 4.727  4.713  4.698  4.678  4.651  4.642  4.635  4.634  4.389  4.405
#   4.425  4.445  4.517  4.549  4.52   4.478  4.43   4.405  4.322  4.285
#   4.25   4.288  4.511  4.542  4.569  4.598  4.626  4.654  4.692  4.731
#   4.102  4.325  4.402  4.455  4.496  4.531  4.56   4.585  4.612  4.642
#   4.654  4.673  4.708  4.759  4.776  4.78   4.783  4.785  4.785  4.787
#   4.793  4.326  4.388  4.438  4.463  4.524  4.547  4.566  4.583  4.594
#   4.599  4.601  4.606  4.611  4.62   4.626  4.079  4.013  4.299  4.403
#   4.448  4.478  4.504  4.524  4.542  4.557  4.571  4.584  4.595  4.605
#   4.617  4.631  4.646  4.656  4.672  4.712  4.772  4.776  4.748  4.727
#   4.704  4.699  4.698  4.691  4.773  4.756  4.746  4.73   4.707  4.676
#   4.631  4.584  4.501  4.417  4.219  4.227  4.237  4.258  4.043  3.887
#   3.84   3.821  4.131  4.067  3.969  4.16   4.18   4.175  4.28   4.353
#   4.358  4.359  4.357  4.355  4.352  4.347  4.335  4.332  4.326  4.288
#   4.27   4.386  4.371  4.343  4.328  4.277  4.209  4.122  3.922  3.893
#   3.893  3.893  3.895  3.895  3.895]
# datasize =  145
