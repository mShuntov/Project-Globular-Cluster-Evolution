# %%
# %matplotlib notebook

# %%
from astropy.io import ascii
import matplotlib.pyplot as plt

# %%
database=ascii.read('asu.csv',format='csv',delimiter=',')

# %%
database.colnames
# Out:
# ['Mo', 'Zo', 'Age', 'Mass', 'logL', 'logTe']

# %%
metallicity=0.02
last_M=99
for M in database['Mo']:
    if last_M != M:
        mask = (database['Mo'] == M) & (database['Zo'] == metallicity)
        #mask = database['Mo'] == 1.50
    
        #plt.figure()
        plt.plot()
        plt.scatter(database['logTe'][mask],database['logL'][mask])
        plt.xlim(5,3.5)
        plt.savefig('HDR_%d.png' % i)
        last_M = M
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#plt.xlim(5,4)
